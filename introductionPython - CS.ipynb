# %% [markdown]
# # déclaration des variables

# %%
name = "Ahmed"           # string
age= 80          # integer
taille = 1.80       # float 

print(name," ",age," ",taille)

name = 5
print(name," ",age," ",taille)


a = b = c =1
name , age, taille = "Ahmed" , 80, 1.80

b=5

print(a," ",b," ",c)
print(name," ",age," ",taille)
# Out:
# Ahmed   80   1.8
# 5   80   1.8
# 1   5   1
# Ahmed   80   1.8

# %%
a, b=9, 2
print(a," ",b)
print("a+b =",a+b)
print("a-b =",a-b)
print("a*b =",a*b)
print("a/b =",a/b)
print("a%b =",a%b)
print("a**b =",a**b)
print("a//b =",a//b)

# %%
a,b=93,60   #01011101
            #00111100
print(a," ",b)
print("a&b =",a&b)
print("a|b =",a|b)
print("a^b =",a^b)
print("~a =",~a)
print("a<<2 =",a<<2)
print("a>>2 =",a>>2)
# Out:
# 93   60
# a&b = 28
# a|b = 125
# a^b = 97
# ~a = -94
# a<<2 = 372
# a>>2 = 23

# %%
str = 'Hello-World!'
print(str)          # affichage de la chaine
print(str[0])       # affichage du premier caractère de la chaine
print(str[1:5])     # affichage des caractères de 2 à 5
print(str[2:])      # affichage de la chaine du 3ème caractère
print(str * 4)      # double affichage de la chaine
print(str[:6] + "python") # affichage de la chaine avec concatination

# %%
ma_liste = [0, "12", 5, "chaine",3.4]

print(ma_liste[1])
print(ma_liste[-2])

ma_liste[0]=10 #modification

print(ma_liste)
# Out:
# 12
# chaine
# [10, '12', 5, 'chaine', 3.4]

# %%
#opérateur +
ma_liste = [0, "12", 5, "chaine"]
ma_liste+= [10]

print(ma_liste)
ma_liste= ["exe"]+ma_liste

print(ma_liste)

#append
ma_liste.append(20) 
print(ma_liste)

#insert
ma_liste.insert(1,23)
print(ma_liste)

#extend
ma_liste.extend([22,"toto"])
print(ma_liste)
liste= [11,5,0,23]
ma_liste.extend(liste)
print("extend ",ma_liste)

#remove
#ma_liste.remove(0)
print("remove ",ma_liste)

#del
del ma_liste[0]
print("del",ma_liste)

ma_liste[1:3]=[]
print(ma_liste)
# Out:
# [0, '12', 5, 'chaine', 10]
# ['exe', 0, '12', 5, 'chaine', 10]
# ['exe', 0, '12', 5, 'chaine', 10, 20]
# ['exe', 23, 0, '12', 5, 'chaine', 10, 20]
# ['exe', 23, 0, '12', 5, 'chaine', 10, 20, 22, 'toto']
# extend  ['exe', 23, 0, '12', 5, 'chaine', 10, 20, 22, 'toto', 11, 5, 0, 23]
# remove  ['exe', 23, 0, '12', 5, 'chaine', 10, 20, 22, 'toto', 11, 5, 0, 23]
# del [23, 0, '12', 5, 'chaine', 10, 20, 22, 'toto', 11, 5, 0, 23]
# [23, 5, 'chaine', 10, 20, 22, 'toto', 11, 5, 0, 23]

# %%
H=[2 *i for i in range (0,11) ] # liste des nombres paires inférieurs à 20 et supérieurs à 0.
print("H=",H)
K=[i for i in range (21) if i%2==0] # les mêmes éléments que ceux de H.
print("K=",K)
M=[n for n in range (0,21,2)] # les mêmes éléments que pour les listes H et K. 
print("M=",M)
N=[x for x in M if x%3!=0] # liste des nombres pairs inférieurs à 20, non multiples de 3. 
print("N=",N)
L=[ i for i in range(0,21,5)]
print("L=",L)
P=[y for y in N if y not in L] # liste des nombres pairs inférieurs à 20, non multiples de 3 et 5.
print("P=",P)

# %%
tuple1 =()   # tuple vide
tuple2 = ('un',) # tuple contient un seul élément n’oublier pas la ,
tuple3 = (1, 45, 85 , 'idx' , 'val', 2) #tuple de données hétérogènes
print(tuple3)
print(tuple3[2])

#tuple2[3]=5

# %% [markdown]
# ### Les dictionnaires

# %%
#Insertion dans un dicio
dico2 = {'inf01' : 'ahmed' , "inf02" : "amine" , "inf03" : "khaled", 4:"youcef" }  
print(dico2)
dico2["inf04"] = "bilal"  
print(dico2)

#Modification
dico2['inf03'] = 'ibrahim'
print(dico2)

#Suppression
del dico2['inf03']  #  supprimer la paire de clé "inf03"
print(dico2)
dico2.clear() # vider le dictionnaire
print(dico2)
del dico2 # supprimer tout le dictionnaire
#print(dico2)

# %%
#Récupérer  les clés 
fruits = {"pommes":21, "raisin":3, "poires":31}

print(fruits.keys())
for cle in fruits.keys():
    print(cle)

#Récupérer les valeurs :
fruits = {"pommes":21, "raisin":3, "poires":31}
for valeur in fruits.values():
    print(valeur)

print(fruits.items())
#Récupérer les clés et les valeurs par une boucle
fruits = {"pommes":21, "raisin":3, "poires":31}
for cle , valeur in fruits.items():
    print(cle,"=>" , valeur)

# %% [markdown]
# ### Manipulation des dictionnaires

# %%
fruits = {"pommes":21, "raisin":3, "poires":31}
#Retourner la liste des clés du dictionnaire
print(fruits.keys())

#Mettre à jour le dictionnaire fruits par le dictionnaire dico1
dico1={"pommes":34,"figues":44}
fruits.update( dico1)
print(fruits)

print(fruits.items()) #Retourner la liste de paires (clé, valeur)

print(fruits.values())  #Retourner la liste des valeurs du dictionnaire fruits

dico2 = fruits
dico2["pommes"]=22
print(fruits.items())
print(dico2.items())

dico3 = fruits.copy() #Retourner une copie du dictionnaire fruits
dico3["pommes"]=33
print(fruits.items())
print(dico3.items())

print(fruits.get("pommes","default")) #Retourne la valeur de la clé "key" si elle existe sinon retourne la valuer "default"

# %% [markdown]
# ## Input & Output

# %%
age = input('votre age : ')

print(age*2)
ageInt = int(age)
print(int(age)*2)
print(age*3)
print(ageInt*3)

# %% [markdown]
# ## les conditions

# %%
x=int(input())
if x%2:
    print(x, ' : est impaire')
else:
    print(x, ' : est paire')

#Multiple conditions elif 
x = int(input())
if x <= 15:
    y = x + 15
elif x <= 30:
    y = x + 30
else:
    y = x
print(' y =', y)

# %% [markdown]
# ## Boucles

# %%
x=1
while x<=10:
    print(x ,'* 7 = ', x*7)
    x+=1

x=1
while x<=10:
    print(x ,'* 7 = ', x*7)
    x+=1
else:
     print('fin de calcul')

# %%
liste=(5, 10, 15, 23, 13, 29)
for nombre in liste:
    print('Le nombre est',nombre)
print('Le nombre est',nombre)
print('Le nombre est',nombre)
print('Le nombre est',nombre)
        

for nombre in range(2, 11, 2):
    print (nombre,' : multiple de 2 :')

print ('\ntable de multiplication de ', nombre)

for nombre2 in range( 11):
    print(nombre, '*', nombre2, '=', nombre*nombre2)

# %%
for x in range(1, 11):
      if x == 5:
                 break
      print(x) 
print ("Boucle interrompue pour x =", x)


for x in range(1, 11):
    if x == 5:
        continue
    print(x, end=" ")

# %% [markdown]
# ## Les fonctions

# %%
def min(a, b):
    a+=4
    if a < b:
        return a
    else:
        return b
    

x=int(input())
y=int(input())
print("le min entre",x, " et ", y , "est :",min(x,y))
print(x)

# %%
def init_List( mylist2 ):
    mylist2+=[0,0,0,0]
    print("Values inside the function : ", mylist2)
    
mylist = [10, 20, 30]
print("Values outside the function: ", mylist)
init_List( mylist[:])
print("Values outside2 the function: ", mylist)
init_List( mylist)
print("Values outside3 the function: ", mylist)

# %%
#argument par défaut 
def printinfo( name, age = 35, taille = 1.80 ):
    print( "Name: ", name)
    print("Age ", age)
    print("taille ", taille)
    

printinfo("Ahmed", 24, 2.10 )
printinfo("Ahmed", 26 )
printinfo("Ahmed", taille=2.10 )
printinfo( "Amine" )

# %% [markdown]
# # les fichiers

# %%
fileIn=open('matRes.txt','r')
contenu = fileIn.read()
print(contenu)

fileIn=open('matRes.txt','r')
#affichage du contenu de fichier ligne par ligne
for line in fileIn:
    print('line:',line.rstrip())

# %%
#affichage du contenu de fichier mot par mot 
file=open('E:\\main.cpp','r')
for line in file:
    words = line.split()
    for word in words:
        print('word :',word)

# %%
#Écriture dans un ﬁchier
langages = ['c++\n', 'java\n', 'python\n', 'scala\n']
#ouverture du fichier en mode écriture
filout = open('file.txt', 'a')
for langage in langages:
    #écriture dans le fichier
    filout.write(langage)
filout.close() #fermer le fichier
